# %% [markdown]
# <a href="https://colab.research.google.com/github/athariqmn97/Finpro-Rakamin-DS56-Kelompok2/blob/main/Churn_Prediction_App.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import streamlit as st
import pandas as pd

# %%
st.title('Churn Prediction - DANN Co. Hi All Sukses to')
